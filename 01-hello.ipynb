# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

arr = np.random.randn(1000)

plt.figure(figsize=(8, 4))
plt.hist(arr, bins=30)
plt.title("My First Notebook!")
plt.show()

print(f"numpy: {np.__version__}")
print(f"pandas: {pd.__version__}")
# Out:
# numpy: 2.4.6
# pandas: 3.0.3
